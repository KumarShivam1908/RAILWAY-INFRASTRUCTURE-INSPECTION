# %% [markdown]
# ### Getting Dataset Ready

# %%
import pandas as pd 
import numpy as np 
import os
import glob as gb
import matplotlib.pyplot as plt 
import cv2

# %%
# from roboflow import Roboflow
# rf = Roboflow(api_key="58BX6EZLXZvWhy5sZjLn")
# project = rf.workspace("intel-challenge").project("bridge-damage-detection-uvjjb")
# version = project.version(3)
# dataset = version.download("multiclass")

# %%
# import os
# import pandas as pd
# import shutil

# # Define the root folder containing train, test, and valid folders
# root_folder = r"C:\Users\shiva\Desktop\EXCEED\ModelWrappers\BridgeDefects\Dinov2\bridge-damage-detection-3"  # Replace with the path to your root folder

# # Define the output folder where the organized dataset will be saved
# output_folder = r"C:\Users\shiva\Desktop\EXCEED\ModelWrappers\BridgeDefects\Dinov2\updated"  # Replace with the desired output folder

# # Define classes based on the columns in the CSV
# classes = ["corrosion", "crack", "freelime", "leakage", "spalling"]

# # Function to count total images in train, test, and valid folders
# def count_total_images():
#     total_images = 0
#     for split in ["train", "test", "valid"]:
#         split_folder = os.path.join(root_folder, split)
#         if os.path.exists(split_folder):
#             # Count only image files (e.g., .jpg, .png)
#             num_images = len([f for f in os.listdir(split_folder) if f.endswith(('.jpg', '.png', '.jpeg'))])
#             print(f"Number of images in {split}: {num_images}")
#             total_images += num_images
#         else:
#             print(f"Folder not found: {split_folder}")
#     print(f"Total images (train + test + valid): {total_images}")

# # Print total number of images
# count_total_images()

# # Create output directories
# for split in ["train", "test", "valid"]:
#     for class_name in classes:
#         os.makedirs(os.path.join(output_folder, split, class_name), exist_ok=True)

# # Function to organize images into class folders
# def organize_images(split_name):
#     # Path to the CSV file
#     csv_file = os.path.join(root_folder, split_name, "_classes.csv")  # Updated CSV file name
#     print(f"Looking for CSV file at: {csv_file}")  # Debugging: Print the CSV file path
    
#     # Path to the split folder (where images are located)
#     split_folder = os.path.join(root_folder, split_name)
#     print(f"Looking for images in folder: {split_folder}")  # Debugging: Print the split folder path
    
#     # Check if CSV file exists
#     if not os.path.exists(csv_file):
#         print(f"CSV file not found: {csv_file}")
#         return
    
#     # Check if split folder exists
#     if not os.path.exists(split_folder):
#         print(f"Split folder not found: {split_folder}")
#         return
    
#     # Read the CSV file
#     data = pd.read_csv(csv_file)
#     data.columns = data.columns.str.strip()  # Remove leading/trailing spaces from column names
    
#     # Organize images
#     for _, row in data.iterrows():
#         filename = row["filename"]
#         for class_name in classes:
#             if row[class_name] == 1:
#                 src_path = os.path.join(split_folder, filename)  # Path to the image in the split folder
#                 dest_path = os.path.join(output_folder, split_name, class_name, filename)  # Path to the output folder
#                 if os.path.exists(src_path):  # Check if the file exists
#                     shutil.copy(src_path, dest_path)  # Copy the image to the class folder
#                 else:
#                     print(f"File not found: {src_path}")  # Debugging: Print if the file is missing

# # Organize images for train, test, and valid splits
# organize_images("train")
# organize_images("test")
# organize_images("valid")

# print("Dataset organized successfully!")

# %%
## train data 
train_data = r'C:\Users\shiva\Desktop\EXCEED\ModelWrappers\BridgeDefects\Dinov2\updated_gs\train'

## test data 
test_data =r'C:\Users\shiva\Desktop\EXCEED\ModelWrappers\BridgeDefects\Dinov2\updated_gs\valid'

# %%
train_images = []
train_labels = []
class_ = {'corrosion': 0, 'crack': 1, 'freelime': 2, 'leakage': 3, 'spalling': 4}

# open train data folder (os, glob)
for folder in os.listdir(train_data):
    folder_path = os.path.join(train_data, folder)
    
    if os.path.isdir(folder_path):
        print(f"Processing folder: {folder}")
        
        data = gb.glob(os.path.join(folder_path, '*.jpg'))
        print(f"Found {len(data)} images in folder {folder}")
        
        image_count = 0  # counter for processed images in this folder
        
        # read train images
        for img_path in data:
            image = cv2.imread(img_path)
            if image is not None:
                image_resized = cv2.resize(image, (100, 100))
                train_images.append(image_resized)
                train_labels.append(class_[folder.strip()])
                image_count += 1
            else:
                print(f"Warning: Could not read image {img_path}")
        
        print(f"Processed {image_count} images from folder {folder}")
    else:
        print(f"Skipping non-folder item: {folder}")

# Final output
print(f"Total images processed: {len(train_images)}")
print(f"Total labels assigned: {len(train_labels)}")
# Out:
# Processing folder: corrosion
# Found 874 images in folder corrosion
# Processed 874 images from folder corrosion
# Processing folder: crack
# Found 1128 images in folder crack
# Processed 1128 images from folder crack
# Processing folder: freelime
# Found 780 images in folder freelime
# Processed 780 images from folder freelime
# Processing folder: leakage
# Found 754 images in folder leakage
# Processed 754 images from folder leakage
# Processing folder: spalling
# Found 986 images in folder spalling
# Processed 986 images from folder spalling
# Total images processed: 4522
# Total labels assigned: 4522

# %%
test_images = []
test_labels = []
class_ = {'corrosion': 0, 'crack': 1, 'freelime': 2, 'leakage': 3, 'spalling': 4}

# open train data folder (os, glob)
for folder in os.listdir(test_data):
    folder_path = os.path.join(test_data, folder)
    
    if os.path.isdir(folder_path):
        print(f"Processing folder: {folder}")
        
        data = gb.glob(os.path.join(folder_path, '*.jpg'))
        print(f"Found {len(data)} images in folder {folder}")
        
        image_count = 0  # counter for processed images in this folder
        
        # read train images
        for img_path in data:
            image = cv2.imread(img_path)
            if image is not None:
                image_resized = cv2.resize(image, (100, 100))
                test_images.append(image_resized)
                test_labels.append(class_[folder.strip()])
                image_count += 1
            else:
                print(f"Warning: Could not read image {img_path}")
        
        print(f"Processed {image_count} images from folder {folder}")
    else:
        print(f"Skipping non-folder item: {folder}")

# Final output
print(f"Total images processed: {len(test_images)}")
print(f"Total labels assigned: {len(test_labels)}")
# Out:
# Processing folder: corrosion
# Found 129 images in folder corrosion
# Processed 129 images from folder corrosion
# Processing folder: crack
# Found 179 images in folder crack
# Processed 179 images from folder crack
# Processing folder: freelime
# Found 102 images in folder freelime
# Processed 102 images from folder freelime
# Processing folder: leakage
# Found 98 images in folder leakage
# Processed 98 images from folder leakage
# Processing folder: spalling
# Found 135 images in folder spalling
# Processed 135 images from folder spalling
# Total images processed: 643
# Total labels assigned: 643

# %%
def get_label(n) : 
    for x , y in class_.items() : 
        if n == y : 
            return x

# %%
plt.figure(figsize=(10, 15))
for n, i in enumerate(np.random.randint(0, len(train_images), 36)):
    plt.subplot(6, 6, n+1)
    # Convert BGR to RGB if necessary
    img_rgb = cv2.cvtColor(train_images[i], cv2.COLOR_BGR2RGB)
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title(get_label(train_labels[i]))

# %%
plt.figure(figsize=(10, 15))
for n, i in enumerate(np.random.randint(0, len(test_images), 36)):
    plt.subplot(6, 6, n+1)
    img_rgb = cv2.cvtColor(test_images[i], cv2.COLOR_BGR2RGB)
    plt.imshow(img_rgb)
    plt.axis('off')
    plt.title(get_label(test_labels[i]))
plt.show()

# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import os
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
from transformers import Dinov2ForImageClassification

# %%
train_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomVerticalFlip(p=0.5),
    transforms.RandomRotation(degrees=15),
])

test_transforms = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# %%
train_path = r'C:\Users\shiva\Desktop\EXCEED\ModelWrappers\BridgeDefects\Dinov2\updated_gs\train'
test_path = r'C:\Users\shiva\Desktop\EXCEED\ModelWrappers\BridgeDefects\Dinov2\updated_gs\valid'

# %%
# Load datasets using ImageFolder
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
train_data = ImageFolder(root=train_path, transform=train_transforms)
test_data = ImageFolder(root=test_path, transform=test_transforms)
num_labels = len(train_data.classes)
print("device", device)
print(f"Number of labels: {num_labels}")

# Data loaders
train_dataloader = DataLoader(dataset=train_data, batch_size=32, shuffle=True, num_workers=0)
test_dataloader = DataLoader(dataset=test_data, batch_size=32, shuffle=False, num_workers=0)


model = Dinov2ForImageClassification.from_pretrained("facebook/dinov2-base", num_labels=num_labels)
model.to(device)
# Out:
# device cuda
# Number of labels: 5
# Some weights of Dinov2ForImageClassification were not initialized from the model checkpoint at facebook/dinov2-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Dinov2ForImageClassification(
#   (dinov2): Dinov2Model(
#     (embeddings): Dinov2Embeddings(
#       (patch_embeddings): Dinov2PatchEmbeddings(
#         (projection): Conv2d(3, 768, kernel_size=(14, 14), stride=(14, 14))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): Dinov2Encoder(
#       (layer): ModuleList(
#         (0-11): 12 x Dinov2Layer(
#           (norm1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (attention): Dinov2SdpaAttention(
#             (attention): Dinov2SdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): Dinov2SelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (layer_scale1): Dinov2LayerScale()
#           (drop_path): Identity()
#           (norm2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): Dinov2MLP(
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (activation): GELUActivation()
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (layer_scale2): Dinov2LayerScale()
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   )
#   (classifier): Linear(in_features=1536, out_features=5, bias=True)
# )

# %%
# Freeze all layers in the DINOv2 model
for param in model.dinov2.parameters():
    param.requires_grad = False

# Unfreeze the classifier
for param in model.classifier.parameters():
    param.requires_grad = True

# %%
from torchinfo import summary
summary(model,
        input_size=(32, 3, 224, 224),
        col_names=["input_size", "output_size", "trainable"],
        col_width=20,
        row_settings=["var_names"])
# Out:
# ==================================================================================================================================
# Layer (type (var_name))                                                Input Shape          Output Shape         Trainable
# ==================================================================================================================================
# Dinov2ForImageClassification (Dinov2ForImageClassification)            [32, 3, 224, 224]    [32, 5]              Partial
# ├─Dinov2Model (dinov2)                                                 [32, 3, 224, 224]    [32, 768]            False
# │    └─Dinov2Embeddings (embeddings)                                   [32, 3, 224, 224]    [32, 257, 768]       False
# │    │    └─Dinov2PatchEmbeddings (patch_embeddings)                   [32, 3, 224, 224]    [32, 256, 768]       False
# │    │    └─Dropout (dropout)                                          [32, 257, 768]       [32, 257, 768]       --
# │    └─Dinov2Encoder (encoder)                                         [32, 257, 768]       [32, 257, 768]       False
# │    │    └─ModuleList (layer)                                         --                   --                   False
# │    └─LayerNorm (layernorm)                                           [32, 257, 768]       [32, 257, 768]       False
# ├─Linear (classifier)                                                  [32, 1536]           [32, 5]              True
# ==================================================================================================================================
# Total params: 86,588,165
# Trainable params: 7,685
# Non-trainable params: 86,580,480
# Total mult-adds (Units.GIGABYTES): 6.43
# ==================================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 7983.27
# Params size (MB): 342.14
# Estimated Total Size (MB): 8344.67
# ==================================================================================================================================

# %%
import torch.optim as optim
loss_fn = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# %%
import time
import numpy as np
from sklearn.metrics import precision_score, recall_score, f1_score
import torch
import torch.nn.functional as F
from tqdm import tqdm
import matplotlib.pyplot as plt
from tabulate import tabulate

# Define your class names
class_names = ["corrosion", "crack", "freelime", "leakage", "spalling"]
num_classes = len(class_names)

# Initialize metrics lists
train_losses = []
test_losses = []
train_accuracies = []
test_accuracies = []
test_latencies = []
train_times = []  # To store training time per epoch

# Move the model to the appropriate device (GPU or CPU)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Use CrossEntropyLoss for multi-class classification
loss_fn = torch.nn.CrossEntropyLoss()

# Training loop
num_epochs = 20
total_train_time = 0  # To accumulate total training time across all epochs

for epoch in range(num_epochs):
    model.train()
    running_loss = 0
    running_corrects = 0
    total_samples = 0

    # Start timer for training phase
    train_start_time = time.time()

    # Training phase
    for batch_idx, (images, labels) in enumerate(train_dataloader):
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images).logits  # Shape: (batch_size, num_classes)
        
        # Calculate loss
        loss = loss_fn(outputs, labels)  # Labels are class indices (not one-hot encoded)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        
        # Get predictions (class with the highest logit)
        preds = torch.argmax(outputs, dim=1)  # Shape: (batch_size)
        
        # Calculate accuracy
        running_corrects += (preds == labels).sum().item()
        total_samples += labels.size(0)

        # Print every 10 batches
        if batch_idx % 10 == 0:
            batch_accuracy = (preds == labels).float().mean()
            print(f"Epoch [{epoch + 1}/{num_epochs}], Batch [{batch_idx}/{len(train_dataloader)}], "
                  f"Loss: {loss.item():.4f}, Batch Accuracy: {batch_accuracy:.4f}")

    # End timer for training phase
    train_end_time = time.time()
    train_time = train_end_time - train_start_time
    train_times.append(train_time)  # Store training time for this epoch
    total_train_time += train_time  # Accumulate total training time

    # Calculate and store epoch-level metrics
    epoch_loss = running_loss / len(train_dataloader)
    epoch_accuracy = running_corrects / total_samples
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)

    print(f"Epoch [{epoch + 1}/{num_epochs}], Average Loss: {epoch_loss:.4f}, "
          f"Epoch Accuracy: {epoch_accuracy:.4f}, Training Time: {train_time:.4f}s")

    # Evaluation on test data
    model.eval()
    test_running_loss = 0
    test_running_corrects = 0
    test_total_samples = 0
    start_time = time.time()

    # Initialize lists to store all predictions and labels for precision, recall, and F1
    all_preds = []
    all_labels = []

    # Reset class-wise metrics at the beginning of evaluation
    total_instances = np.zeros(num_classes)
    correctly_identified = np.zeros(num_classes)
    missed_instances = np.zeros(num_classes)

    with torch.no_grad():
        for images, labels in test_dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images).logits  # Shape: (batch_size, num_classes)
            
            # Calculate loss
            loss = loss_fn(outputs, labels)  # Labels are class indices

            test_running_loss += loss.item()
            
            # Get predictions (class with the highest logit)
            preds = torch.argmax(outputs, dim=1)  # Shape: (batch_size)
            
            # Calculate accuracy
            test_running_corrects += (preds == labels).sum().item()
            test_total_samples += labels.size(0)

            # Store predictions and labels for precision, recall, and F1
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

            # Update class-wise metrics
            for i in range(num_classes):
                total_instances[i] += (labels == i).sum().item()
                correctly_identified[i] += ((preds == i) & (labels == i)).sum().item()
                missed_instances[i] += ((preds != i) & (labels == i)).sum().item()

    end_time = time.time()
    test_loss = test_running_loss / len(test_dataloader)
    test_accuracy = test_running_corrects / test_total_samples
    latency = end_time - start_time

    # Calculate precision, recall, and F1 score
    precision = precision_score(all_labels, all_preds, average='weighted')
    recall = recall_score(all_labels, all_preds, average='weighted')
    f1 = f1_score(all_labels, all_preds, average='weighted')

    # Store test metrics
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)
    test_latencies.append(latency)

    # Print metrics
    print(f"Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}, Latency: {latency:.4f}s")
    print(f"Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}")

    # Calculate and print class-wise accuracy
    class_wise_accuracy = correctly_identified / total_instances
    for i, class_name in enumerate(class_names):
        print(f"Class {class_name} Accuracy: {class_wise_accuracy[i]:.4f}")
# Out:
# Epoch [1/20], Batch [0/142], Loss: 2.5410, Batch Accuracy: 0.1562
# Epoch [1/20], Batch [10/142], Loss: 1.8203, Batch Accuracy: 0.2812
# Epoch [1/20], Batch [20/142], Loss: 1.6300, Batch Accuracy: 0.3438
# Epoch [1/20], Batch [30/142], Loss: 1.5307, Batch Accuracy: 0.3750
# Epoch [1/20], Batch [40/142], Loss: 1.4348, Batch Accuracy: 0.3438
# Epoch [1/20], Batch [50/142], Loss: 1.2164, Batch Accuracy: 0.5938
# Epoch [1/20], Batch [60/142], Loss: 1.3648, Batch Accuracy: 0.3750
# Epoch [1/20], Batch [70/142], Loss: 1.3523, Batch Accuracy: 0.5000
# Epoch [1/20], Batch [80/142], Loss: 0.9892, Batch Accuracy: 0.6250
# Epoch [1/20], Batch [90/142], Loss: 1.3730, Batch Accuracy: 0.3750
# Epoch [1/20], Batch [100/142], Loss: 0.9281, Batch Accuracy: 0.7812
# Epoch [1/20], Batch [110/142], Loss: 1.0654, Batch Accuracy: 0.6875
# Epoch [1/20], Batch [120/142], Loss: 1.0060, Batch Accuracy: 0.6562
# Epoch [1/20], Batch [130/142], Loss: 1.0231, Batch Accuracy: 0.6562
# Epoch [1/20], Batch [140/142], Loss: 1.0495, Batch Accuracy: 0.6250
# Epoch [1/20], Average Loss: 1.2955, Epoch Accuracy: 0.4748, Training Time: 192.4829s
# Test Loss: 1.0436, Test Accuracy: 0.5848, Latency: 26.0873s
# Precision: 0.6010, Recall: 0.5848, F1 Score: 0.5863
# Class corrosion Accuracy: 0.6434
# Class crack Accuracy: 0.7486
# Class freelime Accuracy: 0.3137
# Class leakage Accuracy: 0.6735
# Class spalling Accuracy: 0.4519
# Epoch [2/20], Batch [0/142], Loss: 0.8400, Batch Accuracy: 0.6875
# Epoch [2/20], Batch [10/142], Loss: 1.0535, Batch Accuracy: 0.5625
# Epoch [2/20], Batch [20/142], Loss: 1.0898, Batch Accuracy: 0.5312
# Epoch [2/20], Batch [30/142], Loss: 0.9340, Batch Accuracy: 0.6562
# Epoch [2/20], Batch [40/142], Loss: 1.0778, Batch Accuracy: 0.6250
# Epoch [2/20], Batch [50/142], Loss: 1.0130, Batch Accuracy: 0.5625
# Epoch [2/20], Batch [60/142], Loss: 0.9727, Batch Accuracy: 0.5938
# Epoch [2/20], Batch [70/142], Loss: 0.9205, Batch Accuracy: 0.6250
# Epoch [2/20], Batch [80/142], Loss: 0.9893, Batch Accuracy: 0.5625
# Epoch [2/20], Batch [90/142], Loss: 0.7701, Batch Accuracy: 0.8125
# Epoch [2/20], Batch [100/142], Loss: 0.7979, Batch Accuracy: 0.7188
# Epoch [2/20], Batch [110/142], Loss: 0.7434, Batch Accuracy: 0.6875
# Epoch [2/20], Batch [120/142], Loss: 0.9251, Batch Accuracy: 0.6562
# Epoch [2/20], Batch [130/142], Loss: 0.8432, Batch Accuracy: 0.7188
# Epoch [2/20], Batch [140/142], Loss: 0.9460, Batch Accuracy: 0.5938
# Epoch [2/20], Average Loss: 0.9131, Epoch Accuracy: 0.6387, Training Time: 191.4058s
# Test Loss: 0.9176, Test Accuracy: 0.6221, Latency: 25.8325s
# Precision: 0.6271, Recall: 0.6221, F1 Score: 0.6198
# Class corrosion Accuracy: 0.7364
# Class crack Accuracy: 0.7821
# Class freelime Accuracy: 0.3333
# Class leakage Accuracy: 0.6837
# Class spalling Accuracy: 0.4741
# Epoch [3/20], Batch [0/142], Loss: 0.9630, Batch Accuracy: 0.5938
# Epoch [3/20], Batch [10/142], Loss: 0.7104, Batch Accuracy: 0.6562
# Epoch [3/20], Batch [20/142], Loss: 0.8743, Batch Accuracy: 0.6250
# Epoch [3/20], Batch [30/142], Loss: 0.7214, Batch Accuracy: 0.7500
# Epoch [3/20], Batch [40/142], Loss: 0.6919, Batch Accuracy: 0.7188
# Epoch [3/20], Batch [50/142], Loss: 0.7560, Batch Accuracy: 0.7500
# Epoch [3/20], Batch [60/142], Loss: 0.8843, Batch Accuracy: 0.7812
# Epoch [3/20], Batch [70/142], Loss: 1.0104, Batch Accuracy: 0.6250
# Epoch [3/20], Batch [80/142], Loss: 0.7408, Batch Accuracy: 0.7500
# Epoch [3/20], Batch [90/142], Loss: 0.7707, Batch Accuracy: 0.7188
# Epoch [3/20], Batch [100/142], Loss: 0.7589, Batch Accuracy: 0.6875
# Epoch [3/20], Batch [110/142], Loss: 0.5976, Batch Accuracy: 0.8125
# Epoch [3/20], Batch [120/142], Loss: 0.7654, Batch Accuracy: 0.6562
# Epoch [3/20], Batch [130/142], Loss: 0.6294, Batch Accuracy: 0.7188
# Epoch [3/20], Batch [140/142], Loss: 0.6411, Batch Accuracy: 0.7812
# Epoch [3/20], Average Loss: 0.8147, Epoch Accuracy: 0.6871, Training Time: 187.3665s
# Test Loss: 0.8581, Test Accuracy: 0.6656, Latency: 25.4938s
# Precision: 0.6791, Recall: 0.6656, F1 Score: 0.6694
# Class corrosion Accuracy: 0.7597
# Class crack Accuracy: 0.7877
# Class freelime Accuracy: 0.4510
# Class leakage Accuracy: 0.6735
# Class spalling Accuracy: 0.5704
# Epoch [4/20], Batch [0/142], Loss: 0.7504, Batch Accuracy: 0.7812
# Epoch [4/20], Batch [10/142], Loss: 0.8650, Batch Accuracy: 0.7188
# Epoch [4/20], Batch [20/142], Loss: 0.6793, Batch Accuracy: 0.6562
# Epoch [4/20], Batch [30/142], Loss: 0.8194, Batch Accuracy: 0.7188
# Epoch [4/20], Batch [40/142], Loss: 0.7353, Batch Accuracy: 0.7500
# Epoch [4/20], Batch [50/142], Loss: 0.6831, Batch Accuracy: 0.7812
# Epoch [4/20], Batch [60/142], Loss: 0.8240, Batch Accuracy: 0.6562
# Epoch [4/20], Batch [70/142], Loss: 0.8978, Batch Accuracy: 0.6250
# Epoch [4/20], Batch [80/142], Loss: 0.7796, Batch Accuracy: 0.6250
# Epoch [4/20], Batch [90/142], Loss: 0.5529, Batch Accuracy: 0.8438
# Epoch [4/20], Batch [100/142], Loss: 0.9080, Batch Accuracy: 0.7188
# Epoch [4/20], Batch [110/142], Loss: 0.5481, Batch Accuracy: 0.7500
# Epoch [4/20], Batch [120/142], Loss: 0.4789, Batch Accuracy: 0.8438
# Epoch [4/20], Batch [130/142], Loss: 0.7652, Batch Accuracy: 0.6875
# Epoch [4/20], Batch [140/142], Loss: 0.6884, Batch Accuracy: 0.8125
# Epoch [4/20], Average Loss: 0.7502, Epoch Accuracy: 0.7207, Training Time: 182.3236s
# Test Loss: 0.8223, Test Accuracy: 0.6843, Latency: 24.4229s
# Precision: 0.6997, Recall: 0.6843, F1 Score: 0.6881
# Class corrosion Accuracy: 0.7829
# Class crack Accuracy: 0.7877
# Class freelime Accuracy: 0.4608
# Class leakage Accuracy: 0.6531
# Class spalling Accuracy: 0.6444
# Epoch [5/20], Batch [0/142], Loss: 0.8152, Batch Accuracy: 0.6562
# Epoch [5/20], Batch [10/142], Loss: 0.4577, Batch Accuracy: 0.8750
# Epoch [5/20], Batch [20/142], Loss: 0.6228, Batch Accuracy: 0.7812
# Epoch [5/20], Batch [30/142], Loss: 0.8500, Batch Accuracy: 0.6875
# Epoch [5/20], Batch [40/142], Loss: 0.4609, Batch Accuracy: 0.8438
# Epoch [5/20], Batch [50/142], Loss: 0.8712, Batch Accuracy: 0.6250
# Epoch [5/20], Batch [60/142], Loss: 0.7567, Batch Accuracy: 0.6562
# Epoch [5/20], Batch [70/142], Loss: 0.7525, Batch Accuracy: 0.7188
# Epoch [5/20], Batch [80/142], Loss: 0.6128, Batch Accuracy: 0.7812
# Epoch [5/20], Batch [90/142], Loss: 0.7720, Batch Accuracy: 0.6562
# Epoch [5/20], Batch [100/142], Loss: 0.4926, Batch Accuracy: 0.7812
# Epoch [5/20], Batch [110/142], Loss: 0.4765, Batch Accuracy: 0.8125
# Epoch [5/20], Batch [120/142], Loss: 0.7240, Batch Accuracy: 0.7812
# Epoch [5/20], Batch [130/142], Loss: 0.7312, Batch Accuracy: 0.6562
# Epoch [5/20], Batch [140/142], Loss: 0.6288, Batch Accuracy: 0.7500
# Epoch [5/20], Average Loss: 0.7200, Epoch Accuracy: 0.7333, Training Time: 187.5799s
# Test Loss: 0.8002, Test Accuracy: 0.6967, Latency: 30.1334s
# Precision: 0.7080, Recall: 0.6967, F1 Score: 0.7005
# Class corrosion Accuracy: 0.8062
# Class crack Accuracy: 0.8101
# Class freelime Accuracy: 0.5196
# Class leakage Accuracy: 0.6122
# Class spalling Accuracy: 0.6370
# Epoch [6/20], Batch [0/142], Loss: 0.6829, Batch Accuracy: 0.7500
# Epoch [6/20], Batch [10/142], Loss: 0.7714, Batch Accuracy: 0.7812
# Epoch [6/20], Batch [20/142], Loss: 0.9378, Batch Accuracy: 0.7188
# Epoch [6/20], Batch [30/142], Loss: 0.7644, Batch Accuracy: 0.7812
# Epoch [6/20], Batch [40/142], Loss: 0.6329, Batch Accuracy: 0.7500
# Epoch [6/20], Batch [50/142], Loss: 0.6898, Batch Accuracy: 0.7188
# Epoch [6/20], Batch [60/142], Loss: 0.6122, Batch Accuracy: 0.7812
# Epoch [6/20], Batch [70/142], Loss: 0.6497, Batch Accuracy: 0.7188
# Epoch [6/20], Batch [80/142], Loss: 0.7205, Batch Accuracy: 0.7188
# Epoch [6/20], Batch [90/142], Loss: 0.6114, Batch Accuracy: 0.8125
# Epoch [6/20], Batch [100/142], Loss: 0.7933, Batch Accuracy: 0.6875
# Epoch [6/20], Batch [110/142], Loss: 1.0197, Batch Accuracy: 0.7188
# Epoch [6/20], Batch [120/142], Loss: 0.5485, Batch Accuracy: 0.8438
# Epoch [6/20], Batch [130/142], Loss: 0.5963, Batch Accuracy: 0.7188
# Epoch [6/20], Batch [140/142], Loss: 0.6585, Batch Accuracy: 0.6875
# Epoch [6/20], Average Loss: 0.6995, Epoch Accuracy: 0.7457, Training Time: 211.6734s
# Test Loss: 0.7901, Test Accuracy: 0.7061, Latency: 30.9115s
# Precision: 0.7129, Recall: 0.7061, F1 Score: 0.7077
# Class corrosion Accuracy: 0.8217
# Class crack Accuracy: 0.8156
# Class freelime Accuracy: 0.5098
# Class leakage Accuracy: 0.6735
# Class spalling Accuracy: 0.6222
# Epoch [7/20], Batch [0/142], Loss: 0.6479, Batch Accuracy: 0.8125
# Epoch [7/20], Batch [10/142], Loss: 0.9648, Batch Accuracy: 0.5938
# Epoch [7/20], Batch [20/142], Loss: 0.3322, Batch Accuracy: 0.9375
# Epoch [7/20], Batch [30/142], Loss: 0.5092, Batch Accuracy: 0.8125
# Epoch [7/20], Batch [40/142], Loss: 0.6606, Batch Accuracy: 0.7500
# Epoch [7/20], Batch [50/142], Loss: 0.7131, Batch Accuracy: 0.7188
# Epoch [7/20], Batch [60/142], Loss: 0.4989, Batch Accuracy: 0.7812
# Epoch [7/20], Batch [70/142], Loss: 0.5125, Batch Accuracy: 0.8750
# Epoch [7/20], Batch [80/142], Loss: 0.7069, Batch Accuracy: 0.8438
# Epoch [7/20], Batch [90/142], Loss: 0.7366, Batch Accuracy: 0.7812
# Epoch [7/20], Batch [100/142], Loss: 0.6129, Batch Accuracy: 0.7188
# Epoch [7/20], Batch [110/142], Loss: 0.7932, Batch Accuracy: 0.7812
# Epoch [7/20], Batch [120/142], Loss: 0.8142, Batch Accuracy: 0.7812
# Epoch [7/20], Batch [130/142], Loss: 0.7948, Batch Accuracy: 0.7188
# Epoch [7/20], Batch [140/142], Loss: 0.6564, Batch Accuracy: 0.8125
# Epoch [7/20], Average Loss: 0.6585, Epoch Accuracy: 0.7667, Training Time: 278.1857s
# Test Loss: 0.7749, Test Accuracy: 0.7123, Latency: 26.0787s
# Precision: 0.7221, Recall: 0.7123, F1 Score: 0.7154
# Class corrosion Accuracy: 0.8217
# Class crack Accuracy: 0.8156
# Class freelime Accuracy: 0.5490
# Class leakage Accuracy: 0.6633
# Class spalling Accuracy: 0.6296
# Epoch [8/20], Batch [0/142], Loss: 0.5390, Batch Accuracy: 0.8125
# Epoch [8/20], Batch [10/142], Loss: 0.5124, Batch Accuracy: 0.7812
# Epoch [8/20], Batch [20/142], Loss: 0.8727, Batch Accuracy: 0.6875
# Epoch [8/20], Batch [30/142], Loss: 0.5541, Batch Accuracy: 0.8125
# Epoch [8/20], Batch [40/142], Loss: 0.5716, Batch Accuracy: 0.7500
# Epoch [8/20], Batch [50/142], Loss: 0.8729, Batch Accuracy: 0.7188
# Epoch [8/20], Batch [60/142], Loss: 0.7825, Batch Accuracy: 0.6562
# Epoch [8/20], Batch [70/142], Loss: 0.6072, Batch Accuracy: 0.7500
# Epoch [8/20], Batch [80/142], Loss: 0.5489, Batch Accuracy: 0.8125
# Epoch [8/20], Batch [90/142], Loss: 0.5080, Batch Accuracy: 0.8125
# Epoch [8/20], Batch [100/142], Loss: 0.7772, Batch Accuracy: 0.6875
# Epoch [8/20], Batch [110/142], Loss: 0.5305, Batch Accuracy: 0.8438
# Epoch [8/20], Batch [120/142], Loss: 0.5537, Batch Accuracy: 0.7500
# Epoch [8/20], Batch [130/142], Loss: 0.4955, Batch Accuracy: 0.8750
# Epoch [8/20], Batch [140/142], Loss: 0.8443, Batch Accuracy: 0.6250
# Epoch [8/20], Average Loss: 0.6474, Epoch Accuracy: 0.7634, Training Time: 234.7221s
# Test Loss: 0.7667, Test Accuracy: 0.7123, Latency: 34.5602s
# Precision: 0.7216, Recall: 0.7123, F1 Score: 0.7151
# Class corrosion Accuracy: 0.8217
# Class crack Accuracy: 0.8268
# Class freelime Accuracy: 0.5196
# Class leakage Accuracy: 0.6939
# Class spalling Accuracy: 0.6148
# Epoch [9/20], Batch [0/142], Loss: 0.5665, Batch Accuracy: 0.8125
# Epoch [9/20], Batch [10/142], Loss: 0.6273, Batch Accuracy: 0.7500
# Epoch [9/20], Batch [20/142], Loss: 0.6053, Batch Accuracy: 0.7500
# Epoch [9/20], Batch [30/142], Loss: 0.6673, Batch Accuracy: 0.7812
# Epoch [9/20], Batch [40/142], Loss: 0.7014, Batch Accuracy: 0.7188
# Epoch [9/20], Batch [50/142], Loss: 0.4199, Batch Accuracy: 0.8750
# Epoch [9/20], Batch [60/142], Loss: 0.7639, Batch Accuracy: 0.6250
# Epoch [9/20], Batch [70/142], Loss: 0.7713, Batch Accuracy: 0.7500
# Epoch [9/20], Batch [80/142], Loss: 0.5033, Batch Accuracy: 0.8125
# Epoch [9/20], Batch [90/142], Loss: 0.9300, Batch Accuracy: 0.6250
# Epoch [9/20], Batch [100/142], Loss: 0.7108, Batch Accuracy: 0.6875
# Epoch [9/20], Batch [110/142], Loss: 0.5369, Batch Accuracy: 0.8125
# Epoch [9/20], Batch [120/142], Loss: 0.5640, Batch Accuracy: 0.8750
# Epoch [9/20], Batch [130/142], Loss: 0.6209, Batch Accuracy: 0.6875
# Epoch [9/20], Batch [140/142], Loss: 0.3340, Batch Accuracy: 0.8750
# Epoch [9/20], Average Loss: 0.6309, Epoch Accuracy: 0.7711, Training Time: 215.5206s
# Test Loss: 0.7610, Test Accuracy: 0.7170, Latency: 27.9430s
# Precision: 0.7277, Recall: 0.7170, F1 Score: 0.7196
# Class corrosion Accuracy: 0.8217
# Class crack Accuracy: 0.8101
# Class freelime Accuracy: 0.5098
# Class leakage Accuracy: 0.7041
# Class spalling Accuracy: 0.6593
# Epoch [10/20], Batch [0/142], Loss: 0.6505, Batch Accuracy: 0.7812
# Epoch [10/20], Batch [10/142], Loss: 0.5957, Batch Accuracy: 0.7188
# Epoch [10/20], Batch [20/142], Loss: 0.6949, Batch Accuracy: 0.8125
# Epoch [10/20], Batch [30/142], Loss: 0.5997, Batch Accuracy: 0.7500
# Epoch [10/20], Batch [40/142], Loss: 0.6681, Batch Accuracy: 0.8438
# Epoch [10/20], Batch [50/142], Loss: 0.3554, Batch Accuracy: 0.8750
# Epoch [10/20], Batch [60/142], Loss: 0.7466, Batch Accuracy: 0.7500
# Epoch [10/20], Batch [70/142], Loss: 1.0005, Batch Accuracy: 0.6250
# Epoch [10/20], Batch [80/142], Loss: 0.6936, Batch Accuracy: 0.7188
# Epoch [10/20], Batch [90/142], Loss: 0.6305, Batch Accuracy: 0.8125
# Epoch [10/20], Batch [100/142], Loss: 0.5126, Batch Accuracy: 0.9062
# Epoch [10/20], Batch [110/142], Loss: 0.7856, Batch Accuracy: 0.7500
# Epoch [10/20], Batch [120/142], Loss: 0.4649, Batch Accuracy: 0.8125
# Epoch [10/20], Batch [130/142], Loss: 0.5189, Batch Accuracy: 0.8438
# Epoch [10/20], Batch [140/142], Loss: 0.4109, Batch Accuracy: 0.9062
# Epoch [10/20], Average Loss: 0.6200, Epoch Accuracy: 0.7804, Training Time: 225.6880s
# Test Loss: 0.7570, Test Accuracy: 0.7154, Latency: 25.0106s
# Precision: 0.7275, Recall: 0.7154, F1 Score: 0.7181
# Class corrosion Accuracy: 0.8217
# Class crack Accuracy: 0.8101
# Class freelime Accuracy: 0.5098
# Class leakage Accuracy: 0.6939
# Class spalling Accuracy: 0.6593
# Epoch [11/20], Batch [0/142], Loss: 0.4328, Batch Accuracy: 0.8750
# Epoch [11/20], Batch [10/142], Loss: 0.6297, Batch Accuracy: 0.7500
# Epoch [11/20], Batch [20/142], Loss: 0.4154, Batch Accuracy: 0.9062
# Epoch [11/20], Batch [30/142], Loss: 0.6063, Batch Accuracy: 0.6875
# Epoch [11/20], Batch [40/142], Loss: 0.7071, Batch Accuracy: 0.7500
# Epoch [11/20], Batch [50/142], Loss: 0.5929, Batch Accuracy: 0.7812
# Epoch [11/20], Batch [60/142], Loss: 0.8203, Batch Accuracy: 0.6875
# Epoch [11/20], Batch [70/142], Loss: 0.5525, Batch Accuracy: 0.7812
# Epoch [11/20], Batch [80/142], Loss: 0.6471, Batch Accuracy: 0.7500
# Epoch [11/20], Batch [90/142], Loss: 0.5515, Batch Accuracy: 0.8438
# Epoch [11/20], Batch [100/142], Loss: 0.8275, Batch Accuracy: 0.6875
# Epoch [11/20], Batch [110/142], Loss: 0.4294, Batch Accuracy: 0.8438
# Epoch [11/20], Batch [120/142], Loss: 0.6077, Batch Accuracy: 0.6875
# Epoch [11/20], Batch [130/142], Loss: 0.6138, Batch Accuracy: 0.7188
# Epoch [11/20], Batch [140/142], Loss: 0.6439, Batch Accuracy: 0.7188
# Epoch [11/20], Average Loss: 0.6039, Epoch Accuracy: 0.7802, Training Time: 186.1087s
# Test Loss: 0.7611, Test Accuracy: 0.7247, Latency: 24.5417s
# Precision: 0.7376, Recall: 0.7247, F1 Score: 0.7282
# Class corrosion Accuracy: 0.8217
# Class crack Accuracy: 0.8156
# Class freelime Accuracy: 0.5588
# Class leakage Accuracy: 0.7449
# Class spalling Accuracy: 0.6222
# Epoch [12/20], Batch [0/142], Loss: 0.8682, Batch Accuracy: 0.5938
# Epoch [12/20], Batch [10/142], Loss: 0.6204, Batch Accuracy: 0.8125
# Epoch [12/20], Batch [20/142], Loss: 0.5944, Batch Accuracy: 0.8125
# Epoch [12/20], Batch [30/142], Loss: 0.4547, Batch Accuracy: 0.8438
# Epoch [12/20], Batch [40/142], Loss: 0.6987, Batch Accuracy: 0.6875
# Epoch [12/20], Batch [50/142], Loss: 0.5972, Batch Accuracy: 0.7812
# Epoch [12/20], Batch [60/142], Loss: 0.5815, Batch Accuracy: 0.7500
# Epoch [12/20], Batch [70/142], Loss: 0.5694, Batch Accuracy: 0.8125
# Epoch [12/20], Batch [80/142], Loss: 0.5014, Batch Accuracy: 0.8438
# Epoch [12/20], Batch [90/142], Loss: 0.5895, Batch Accuracy: 0.7812
# Epoch [12/20], Batch [100/142], Loss: 0.6771, Batch Accuracy: 0.6875
# Epoch [12/20], Batch [110/142], Loss: 0.7703, Batch Accuracy: 0.6875
# Epoch [12/20], Batch [120/142], Loss: 0.6613, Batch Accuracy: 0.7500
# Epoch [12/20], Batch [130/142], Loss: 0.6090, Batch Accuracy: 0.7188
# Epoch [12/20], Batch [140/142], Loss: 0.9339, Batch Accuracy: 0.7188
# Epoch [12/20], Average Loss: 0.5947, Epoch Accuracy: 0.7870, Training Time: 185.8982s
# Test Loss: 0.7363, Test Accuracy: 0.7325, Latency: 25.0822s
# Precision: 0.7425, Recall: 0.7325, F1 Score: 0.7358
# Class corrosion Accuracy: 0.8217
# Class crack Accuracy: 0.8212
# Class freelime Accuracy: 0.6078
# Class leakage Accuracy: 0.6735
# Class spalling Accuracy: 0.6667
# Epoch [13/20], Batch [0/142], Loss: 0.5748, Batch Accuracy: 0.8125
# Epoch [13/20], Batch [10/142], Loss: 0.7484, Batch Accuracy: 0.7500
# Epoch [13/20], Batch [20/142], Loss: 0.6795, Batch Accuracy: 0.7500
# Epoch [13/20], Batch [30/142], Loss: 0.7763, Batch Accuracy: 0.6875
# Epoch [13/20], Batch [40/142], Loss: 0.5776, Batch Accuracy: 0.8125
# Epoch [13/20], Batch [50/142], Loss: 0.4241, Batch Accuracy: 0.8438
# Epoch [13/20], Batch [60/142], Loss: 0.4067, Batch Accuracy: 0.8750
# Epoch [13/20], Batch [70/142], Loss: 0.3775, Batch Accuracy: 0.9062
# Epoch [13/20], Batch [80/142], Loss: 0.8875, Batch Accuracy: 0.5625
# Epoch [13/20], Batch [90/142], Loss: 0.6418, Batch Accuracy: 0.8750
# Epoch [13/20], Batch [100/142], Loss: 0.3626, Batch Accuracy: 0.9062
# Epoch [13/20], Batch [110/142], Loss: 0.6220, Batch Accuracy: 0.7500
# Epoch [13/20], Batch [120/142], Loss: 0.8501, Batch Accuracy: 0.6875
# Epoch [13/20], Batch [130/142], Loss: 0.4432, Batch Accuracy: 0.8750
# Epoch [13/20], Batch [140/142], Loss: 0.3971, Batch Accuracy: 0.8750
# Epoch [13/20], Average Loss: 0.5872, Epoch Accuracy: 0.7915, Training Time: 191.2720s
# Test Loss: 0.7381, Test Accuracy: 0.7216, Latency: 26.0646s
# Precision: 0.7354, Recall: 0.7216, F1 Score: 0.7263
# Class corrosion Accuracy: 0.8217
# Class crack Accuracy: 0.8045
# Class freelime Accuracy: 0.5980
# Class leakage Accuracy: 0.6837
# Class spalling Accuracy: 0.6370
# Epoch [14/20], Batch [0/142], Loss: 0.7326, Batch Accuracy: 0.7500
# Epoch [14/20], Batch [10/142], Loss: 0.4081, Batch Accuracy: 0.9062
# Epoch [14/20], Batch [20/142], Loss: 0.7695, Batch Accuracy: 0.7188
# Epoch [14/20], Batch [30/142], Loss: 0.6254, Batch Accuracy: 0.7812
# Epoch [14/20], Batch [40/142], Loss: 0.6300, Batch Accuracy: 0.8125
# Epoch [14/20], Batch [50/142], Loss: 0.7131, Batch Accuracy: 0.7188
# Epoch [14/20], Batch [60/142], Loss: 0.5752, Batch Accuracy: 0.8438
# Epoch [14/20], Batch [70/142], Loss: 0.6049, Batch Accuracy: 0.6875
# Epoch [14/20], Batch [80/142], Loss: 0.7293, Batch Accuracy: 0.6875
# Epoch [14/20], Batch [90/142], Loss: 0.4905, Batch Accuracy: 0.8125
# Epoch [14/20], Batch [100/142], Loss: 0.5977, Batch Accuracy: 0.8125
# Epoch [14/20], Batch [110/142], Loss: 0.5811, Batch Accuracy: 0.8125
# Epoch [14/20], Batch [120/142], Loss: 0.4532, Batch Accuracy: 0.8125
# Epoch [14/20], Batch [130/142], Loss: 0.6802, Batch Accuracy: 0.7500
# Epoch [14/20], Batch [140/142], Loss: 0.5109, Batch Accuracy: 0.8125
# Epoch [14/20], Average Loss: 0.5707, Epoch Accuracy: 0.7974, Training Time: 191.4870s
# Test Loss: 0.7418, Test Accuracy: 0.7232, Latency: 25.8867s
# Precision: 0.7366, Recall: 0.7232, F1 Score: 0.7266
# Class corrosion Accuracy: 0.8450
# Class crack Accuracy: 0.8045
# Class freelime Accuracy: 0.5686
# Class leakage Accuracy: 0.6939
# Class spalling Accuracy: 0.6370
# Epoch [15/20], Batch [0/142], Loss: 0.5722, Batch Accuracy: 0.8125
# Epoch [15/20], Batch [10/142], Loss: 0.6385, Batch Accuracy: 0.8125
# Epoch [15/20], Batch [20/142], Loss: 0.6146, Batch Accuracy: 0.7188
# Epoch [15/20], Batch [30/142], Loss: 0.4272, Batch Accuracy: 0.8438
# Epoch [15/20], Batch [40/142], Loss: 0.8757, Batch Accuracy: 0.8125
# Epoch [15/20], Batch [50/142], Loss: 0.6982, Batch Accuracy: 0.7188
# Epoch [15/20], Batch [60/142], Loss: 0.6358, Batch Accuracy: 0.8750
# Epoch [15/20], Batch [70/142], Loss: 0.6094, Batch Accuracy: 0.8438
# Epoch [15/20], Batch [80/142], Loss: 0.3819, Batch Accuracy: 0.8750
# Epoch [15/20], Batch [90/142], Loss: 0.8951, Batch Accuracy: 0.7500
# Epoch [15/20], Batch [100/142], Loss: 0.5094, Batch Accuracy: 0.7188
# Epoch [15/20], Batch [110/142], Loss: 0.3742, Batch Accuracy: 0.8750
# Epoch [15/20], Batch [120/142], Loss: 0.5336, Batch Accuracy: 0.8750
# Epoch [15/20], Batch [130/142], Loss: 0.6511, Batch Accuracy: 0.7812
# Epoch [15/20], Batch [140/142], Loss: 0.5464, Batch Accuracy: 0.8438
# Epoch [15/20], Average Loss: 0.5607, Epoch Accuracy: 0.8069, Training Time: 189.1863s
# Test Loss: 0.7471, Test Accuracy: 0.7170, Latency: 25.5703s
# Precision: 0.7306, Recall: 0.7170, F1 Score: 0.7193
# Class corrosion Accuracy: 0.8295
# Class crack Accuracy: 0.8156
# Class freelime Accuracy: 0.4804
# Class leakage Accuracy: 0.7347
# Class spalling Accuracy: 0.6444
# Epoch [16/20], Batch [0/142], Loss: 0.5860, Batch Accuracy: 0.7188
# Epoch [16/20], Batch [10/142], Loss: 0.8227, Batch Accuracy: 0.7812
# Epoch [16/20], Batch [20/142], Loss: 0.4957, Batch Accuracy: 0.8125
# Epoch [16/20], Batch [30/142], Loss: 0.3238, Batch Accuracy: 0.9375
# Epoch [16/20], Batch [40/142], Loss: 0.5373, Batch Accuracy: 0.8125
# Epoch [16/20], Batch [50/142], Loss: 0.6773, Batch Accuracy: 0.7188
# Epoch [16/20], Batch [60/142], Loss: 0.5003, Batch Accuracy: 0.8750
# Epoch [16/20], Batch [70/142], Loss: 0.4595, Batch Accuracy: 0.8438
# Epoch [16/20], Batch [80/142], Loss: 0.5756, Batch Accuracy: 0.7812
# Epoch [16/20], Batch [90/142], Loss: 0.7093, Batch Accuracy: 0.7188
# Epoch [16/20], Batch [100/142], Loss: 0.5330, Batch Accuracy: 0.8125
# Epoch [16/20], Batch [110/142], Loss: 0.4380, Batch Accuracy: 0.8438
# Epoch [16/20], Batch [120/142], Loss: 0.6608, Batch Accuracy: 0.6250
# Epoch [16/20], Batch [130/142], Loss: 0.5566, Batch Accuracy: 0.8438
# Epoch [16/20], Batch [140/142], Loss: 0.4132, Batch Accuracy: 0.8438
# Epoch [16/20], Average Loss: 0.5584, Epoch Accuracy: 0.8025, Training Time: 214.3028s
# Test Loss: 0.7299, Test Accuracy: 0.7387, Latency: 24.9681s
# Precision: 0.7502, Recall: 0.7387, F1 Score: 0.7416
# Class corrosion Accuracy: 0.8295
# Class crack Accuracy: 0.8212
# Class freelime Accuracy: 0.5686
# Class leakage Accuracy: 0.6735
# Class spalling Accuracy: 0.7185
# Epoch [17/20], Batch [0/142], Loss: 0.6023, Batch Accuracy: 0.7500
# Epoch [17/20], Batch [10/142], Loss: 0.7976, Batch Accuracy: 0.7500
# Epoch [17/20], Batch [20/142], Loss: 0.3608, Batch Accuracy: 0.9375
# Epoch [17/20], Batch [30/142], Loss: 0.6282, Batch Accuracy: 0.7500
# Epoch [17/20], Batch [40/142], Loss: 0.5372, Batch Accuracy: 0.8438
# Epoch [17/20], Batch [50/142], Loss: 0.5760, Batch Accuracy: 0.8125
# Epoch [17/20], Batch [60/142], Loss: 0.6034, Batch Accuracy: 0.8125
# Epoch [17/20], Batch [70/142], Loss: 0.4923, Batch Accuracy: 0.7500
# Epoch [17/20], Batch [80/142], Loss: 0.3073, Batch Accuracy: 0.9062
# Epoch [17/20], Batch [90/142], Loss: 0.5238, Batch Accuracy: 0.8750
# Epoch [17/20], Batch [100/142], Loss: 0.3070, Batch Accuracy: 0.9062
# Epoch [17/20], Batch [110/142], Loss: 0.6856, Batch Accuracy: 0.7500
# Epoch [17/20], Batch [120/142], Loss: 0.5146, Batch Accuracy: 0.8125
# Epoch [17/20], Batch [130/142], Loss: 0.3411, Batch Accuracy: 0.8750
# Epoch [17/20], Batch [140/142], Loss: 0.5036, Batch Accuracy: 0.8438
# Epoch [17/20], Average Loss: 0.5485, Epoch Accuracy: 0.8076, Training Time: 187.8937s
# Test Loss: 0.7390, Test Accuracy: 0.7325, Latency: 25.4175s
# Precision: 0.7465, Recall: 0.7325, F1 Score: 0.7364
# Class corrosion Accuracy: 0.8295
# Class crack Accuracy: 0.8101
# Class freelime Accuracy: 0.5686
# Class leakage Accuracy: 0.6939
# Class spalling Accuracy: 0.6889
# Epoch [18/20], Batch [0/142], Loss: 0.6269, Batch Accuracy: 0.8750
# Epoch [18/20], Batch [10/142], Loss: 0.5835, Batch Accuracy: 0.8125
# Epoch [18/20], Batch [20/142], Loss: 0.4951, Batch Accuracy: 0.8125
# Epoch [18/20], Batch [30/142], Loss: 0.4356, Batch Accuracy: 0.8438
# Epoch [18/20], Batch [40/142], Loss: 0.7448, Batch Accuracy: 0.8125
# Epoch [18/20], Batch [50/142], Loss: 0.6306, Batch Accuracy: 0.7500
# Epoch [18/20], Batch [60/142], Loss: 0.4889, Batch Accuracy: 0.9062
# Epoch [18/20], Batch [70/142], Loss: 0.7813, Batch Accuracy: 0.7188
# Epoch [18/20], Batch [80/142], Loss: 0.5002, Batch Accuracy: 0.7812
# Epoch [18/20], Batch [90/142], Loss: 0.3613, Batch Accuracy: 0.9375
# Epoch [18/20], Batch [100/142], Loss: 0.3432, Batch Accuracy: 0.9062
# Epoch [18/20], Batch [110/142], Loss: 0.2556, Batch Accuracy: 0.9688
# Epoch [18/20], Batch [120/142], Loss: 0.6094, Batch Accuracy: 0.7188
# Epoch [18/20], Batch [130/142], Loss: 0.4168, Batch Accuracy: 0.9062
# Epoch [18/20], Batch [140/142], Loss: 0.4904, Batch Accuracy: 0.9062
# Epoch [18/20], Average Loss: 0.5394, Epoch Accuracy: 0.8092, Training Time: 224.8065s
# Test Loss: 0.7316, Test Accuracy: 0.7325, Latency: 25.6864s
# Precision: 0.7471, Recall: 0.7325, F1 Score: 0.7356
# Class corrosion Accuracy: 0.8217
# Class crack Accuracy: 0.8156
# Class freelime Accuracy: 0.5392
# Class leakage Accuracy: 0.6939
# Class spalling Accuracy: 0.7111
# Epoch [19/20], Batch [0/142], Loss: 0.7045, Batch Accuracy: 0.7188
# Epoch [19/20], Batch [10/142], Loss: 0.4827, Batch Accuracy: 0.8125
# Epoch [19/20], Batch [20/142], Loss: 0.8927, Batch Accuracy: 0.6250
# Epoch [19/20], Batch [30/142], Loss: 0.8701, Batch Accuracy: 0.6562
# Epoch [19/20], Batch [40/142], Loss: 0.4738, Batch Accuracy: 0.8750
# Epoch [19/20], Batch [50/142], Loss: 0.6405, Batch Accuracy: 0.8438
# Epoch [19/20], Batch [60/142], Loss: 0.6737, Batch Accuracy: 0.7500
# Epoch [19/20], Batch [70/142], Loss: 0.5179, Batch Accuracy: 0.7812
# Epoch [19/20], Batch [80/142], Loss: 0.5356, Batch Accuracy: 0.7812
# Epoch [19/20], Batch [90/142], Loss: 0.3977, Batch Accuracy: 0.8750
# Epoch [19/20], Batch [100/142], Loss: 0.5819, Batch Accuracy: 0.7812
# Epoch [19/20], Batch [110/142], Loss: 0.7838, Batch Accuracy: 0.7812
# Epoch [19/20], Batch [120/142], Loss: 0.4067, Batch Accuracy: 0.8125
# Epoch [19/20], Batch [130/142], Loss: 0.5821, Batch Accuracy: 0.7188
# Epoch [19/20], Batch [140/142], Loss: 0.5285, Batch Accuracy: 0.8750
# Epoch [19/20], Average Loss: 0.5305, Epoch Accuracy: 0.8180, Training Time: 189.5679s
# Test Loss: 0.7330, Test Accuracy: 0.7356, Latency: 25.3861s
# Precision: 0.7511, Recall: 0.7356, F1 Score: 0.7410
# Class corrosion Accuracy: 0.8140
# Class crack Accuracy: 0.8045
# Class freelime Accuracy: 0.6275
# Class leakage Accuracy: 0.7041
# Class spalling Accuracy: 0.6741
# Epoch [20/20], Batch [0/142], Loss: 0.3519, Batch Accuracy: 0.8750
# Epoch [20/20], Batch [10/142], Loss: 0.5483, Batch Accuracy: 0.8750
# Epoch [20/20], Batch [20/142], Loss: 0.4760, Batch Accuracy: 0.9062
# Epoch [20/20], Batch [30/142], Loss: 0.5026, Batch Accuracy: 0.7812
# Epoch [20/20], Batch [40/142], Loss: 0.4465, Batch Accuracy: 0.8125
# Epoch [20/20], Batch [50/142], Loss: 0.5463, Batch Accuracy: 0.7500
# Epoch [20/20], Batch [60/142], Loss: 0.5357, Batch Accuracy: 0.8438
# Epoch [20/20], Batch [70/142], Loss: 0.7306, Batch Accuracy: 0.7812
# Epoch [20/20], Batch [80/142], Loss: 0.7249, Batch Accuracy: 0.6875
# Epoch [20/20], Batch [90/142], Loss: 0.9470, Batch Accuracy: 0.6875
# Epoch [20/20], Batch [100/142], Loss: 0.5940, Batch Accuracy: 0.8125
# Epoch [20/20], Batch [110/142], Loss: 0.7715, Batch Accuracy: 0.5938
# Epoch [20/20], Batch [120/142], Loss: 0.5955, Batch Accuracy: 0.7188
# Epoch [20/20], Batch [130/142], Loss: 0.8129, Batch Accuracy: 0.6250
# Epoch [20/20], Batch [140/142], Loss: 0.7213, Batch Accuracy: 0.6562
# Epoch [20/20], Average Loss: 0.5280, Epoch Accuracy: 0.8215, Training Time: 191.5799s
# Test Loss: 0.7376, Test Accuracy: 0.7372, Latency: 28.2581s
# Precision: 0.7471, Recall: 0.7372, F1 Score: 0.7394
# Class corrosion Accuracy: 0.8450
# Class crack Accuracy: 0.8212
# Class freelime Accuracy: 0.6667
# Class leakage Accuracy: 0.6939
# Class spalling Accuracy: 0.6074

# %%
def visualize_class_metrics(class_names, total_instances, correctly_identified, missed_instances):
    """
    Create a bar plot showing identification results for each class.
    """
    # Calculate identification rates
    identification_rates = correctly_identified / total_instances * 100
    missed_rates = missed_instances / total_instances * 100

    # Prepare the plot
    plt.figure(figsize=(10, 6))
    
    # Create bar positions
    x = np.arange(len(class_names))
    width = 0.35

    # Plot correctly identified instances
    plt.bar(x - width/2, correctly_identified, width, label='Correctly Identified', color='green')
    
    # Plot missed instances
    plt.bar(x + width/2, missed_instances, width, label='Missed', color='red')

    # Customize the plot
    plt.xlabel('Classes')
    plt.ylabel('Number of Instances')
    plt.title('Class-wise Identification Results')
    plt.xticks(x, class_names, rotation=45)
    plt.legend()

    # Add text annotations for identification rates
    for i, rate in enumerate(identification_rates):
        plt.text(x[i], max(correctly_identified[i], missed_instances[i]) + 5, 
                 f'{rate:.1f}%', ha='center', va='bottom')

    plt.tight_layout()
    plt.show()

    # Create a summary table
    print("\nClass-wise Identification Summary:")
    print("{:<10} {:<15} {:<20} {:<15} {:<15}".format(
        "Class", "Total Instances", "Correctly Identified", "Missed", "ID Rate"))
    print("-" * 75)
    for i, name in enumerate(class_names):
        print("{:<10} {:<15} {:<20} {:<15} {:<15.1f}%".format(
            name, 
            total_instances[i], 
            correctly_identified[i], 
            missed_instances[i], 
            identification_rates[i]
        ))

# Visualize final class-wise metrics
visualize_class_metrics(class_names, total_instances, correctly_identified, missed_instances)

# Print total training time
print(f"\nTotal Training Time: {total_train_time:.4f}s")
# Out:
# Class-wise Identification Summary:
# Class      Total Instances Correctly Identified Missed          ID Rate
# ---------------------------------------------------------------------------
# corrosion  129.0           109.0                20.0            84.5           %
# crack      179.0           147.0                32.0            82.1           %
# freelime   102.0           68.0                 34.0            66.7           %
# leakage    98.0            68.0                 30.0            69.4           %
# spalling   135.0           82.0                 53.0            60.7           %
#
# Total Training Time: 4059.0513s

# %%
def display_final_metrics_table():
    """
    Display final metrics in a compact table format
    """
    final_metrics = [
        ["Final Test Loss", test_losses[-1]],
        ["Final Test Accuracy", test_accuracies[-1]],
        ["Precision", precision],
        ["Recall", recall],
        ["F1 Score", f1],
        ["Total Training Time", total_train_time]
    ]

    print("\nFinal Model Performance Metrics:")
    print(tabulate(final_metrics, tablefmt="simple"))

def plot_final_metrics():
    """
    Plot final performance metrics across epochs
    """
    plt.figure(figsize=(15, 5))

    # Loss plot
    plt.subplot(1, 3, 1)
    plt.plot(train_losses, label="Train Loss", marker="o")
    plt.plot(test_losses, label="Test Loss", marker="o")
    plt.title("Loss Progression")
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.legend()

    # Accuracy plot
    plt.subplot(1, 3, 2)
    plt.plot(train_accuracies, label="Train Accuracy", marker="o")
    plt.plot(test_accuracies, label="Test Accuracy", marker="o")
    plt.title("Accuracy Progression")
    plt.xlabel("Epoch")
    plt.ylabel("Accuracy")
    plt.legend()

    # Training time plot
    plt.subplot(1, 3, 3)
    plt.plot(train_times, label="Training Time", marker="o", color="green")
    plt.title("Training Time per Epoch")
    plt.xlabel("Epoch")
    plt.ylabel("Time (s)")
    plt.legend()

    plt.tight_layout()
    plt.show()

# Display final metrics table
display_final_metrics_table()

# Plot metrics progression
plot_final_metrics()
# Out:
# Final Model Performance Metrics:
# -------------------  -----------
# Final Test Loss         0.737607
# Final Test Accuracy     0.73717
# Precision               0.747057
# Recall                  0.73717
# F1 Score                0.739414
# Total Training Time  4059.05
# -------------------  -----------

# %%
def plot_latency(test_latencies):
    plt.figure(figsize=(10, 5))
    plt.plot(test_latencies, label="Test Latency", marker="o", color="red")
    plt.title("Test Latency per Epoch")
    plt.xlabel("Epoch")
    plt.ylabel("Latency (seconds)")
    plt.legend()
    plt.grid(True)
    plt.show()

plot_latency(test_latencies)

# %%
torch.save(model.state_dict(), 'dinov2_backboned_grayscale.pth')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, roc_curve, auc, ConfusionMatrixDisplay


# Load the pre-trained DINOv2 model for binary classification
model_dino = Dinov2ForImageClassification.from_pretrained("facebook/dinov2-base", num_labels=5)
model_dino.classifier = torch.nn.Linear(model_dino.classifier.in_features, 5)
model_dino.load_state_dict(torch.load(r'C:\Users\shiva\Desktop\EXCEED\ModelWrappers\BridgeDefects\Dinov2\dinov2_backboned_grayscale.pth'))

for param in model_dino.dinov2.parameters():
    param.requires_grad = False  

# Ensure the classifier is trainable
for param in model_dino.classifier.parameters():
    param.requires_grad = True  


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model_dino.to(device)


summary(model_dino,
        input_size=(32, 3, 224, 224),
        col_names=["input_size", "output_size", "trainable"],
        col_width=20,
        row_settings=["var_names"])
# Out:
# Some weights of Dinov2ForImageClassification were not initialized from the model checkpoint at facebook/dinov2-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
# ==================================================================================================================================
# Layer (type (var_name))                                                Input Shape          Output Shape         Trainable
# ==================================================================================================================================
# Dinov2ForImageClassification (Dinov2ForImageClassification)            [32, 3, 224, 224]    [32, 5]              Partial
# ├─Dinov2Model (dinov2)                                                 [32, 3, 224, 224]    [32, 768]            False
# │    └─Dinov2Embeddings (embeddings)                                   [32, 3, 224, 224]    [32, 257, 768]       False
# │    │    └─Dinov2PatchEmbeddings (patch_embeddings)                   [32, 3, 224, 224]    [32, 256, 768]       False
# │    │    └─Dropout (dropout)                                          [32, 257, 768]       [32, 257, 768]       --
# │    └─Dinov2Encoder (encoder)                                         [32, 257, 768]       [32, 257, 768]       False
# │    │    └─ModuleList (layer)                                         --                   --                   False
# │    └─LayerNorm (layernorm)                                           [32, 257, 768]       [32, 257, 768]       False
# ├─Linear (classifier)                                                  [32, 1536]           [32, 5]              True
# ==================================================================================================================================
# Total params: 86,588,165
# Trainable params: 7,685
# Non-trainable params: 86,580,480
# Total mult-adds (Units.GIGABYTES): 6.43
# ==================================================================================================================================
# Input size (MB): 19.27
# Forward/backward pass size (MB): 7983.27
# Params size (MB): 342.14
# Estimated Total Size (MB): 8344.67
# ==================================================================================================================================

# %%
import time
import random
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score, roc_curve, auc
from sklearn.preprocessing import label_binarize
import pandas as pd

# Function to evaluate the model
def evaluate_model(model, dataloader, device, class_names):
    model.eval()
    running_corrects = 0
    total_samples = 0
    total_latency = 0
    all_preds = []
    all_labels = []
    all_images = []
    all_probs = []

    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)

            start_time = time.time()
            outputs = model(images)
            end_time = time.time()

            total_latency += (end_time - start_time) * 1000  # Convert to milliseconds

            if hasattr(outputs, 'logits'):
                logits = outputs.logits
            else:
                logits = outputs  # For models without a 'logits' attribute

            probs = torch.softmax(logits, dim=1)  # Get probabilities for each class
            preds = torch.argmax(probs, dim=1)  # Get predicted class

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
            all_images.extend(images.cpu().numpy())  # Store images for display
            all_probs.extend(probs.cpu().numpy())  # Store probabilities for ROC curve

            running_corrects += (preds == labels).sum().item()
            total_samples += labels.size(0)

    accuracy = (running_corrects / total_samples) * 100
    avg_latency = total_latency / total_samples if total_samples > 0 else 0

    # Calculate precision, recall, and F1 score
    precision = precision_score(all_labels, all_preds, average='weighted')
    recall = recall_score(all_labels, all_preds, average='weighted')
    f1 = f1_score(all_labels, all_preds, average='weighted')

    return accuracy, avg_latency, all_labels, all_preds, all_images, all_probs, precision, recall, f1

# Evaluate DINOv2 model
dino_accuracy, dino_latency, dino_labels, dino_preds, dino_images, dino_probs, dino_precision, dino_recall, dino_f1 = evaluate_model(
    model_dino, test_dataloader, device, class_names
)

# Function to display images and predictions
def display_predictions(images, labels, preds, class_names, model_name):
    plt.figure(figsize=(12, 12))
    random_indices = random.sample(range(len(images)), min(9, len(images)))  # Random selection of images
    for i in random_indices:
        plt.subplot(3, 3, random_indices.index(i) + 1)
        img = images[i].transpose(1, 2, 0)  # Transpose to get (H, W, C)
        img = (img - img.min()) / (img.max() - img.min())  # Normalize to [0, 1]
        
        plt.imshow(img)  # Use the RGB image
        plt.title(f'True: {class_names[labels[i]]}\nPred: {class_names[preds[i]]}')
        plt.axis('off')
    plt.suptitle(f'Predictions from {model_name}', fontsize=16)
    plt.show()

# Display predictions for DINOv2
display_predictions(dino_images, dino_labels, dino_preds, class_names, 'DINOv2')

# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, class_names, model_name):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False,
                xticklabels=class_names, yticklabels=class_names)
    plt.title(f'Confusion Matrix for {model_name}')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# Plot confusion matrix for DINOv2
plot_confusion_matrix(dino_labels, dino_preds, class_names, 'DINOv2')

# Function to plot ROC curve (One-vs-Rest for multiclass)
def plot_roc_curve(y_true, y_probs, class_names, model_name):
    y_true_bin = label_binarize(y_true, classes=range(len(class_names)))  # Binarize labels
    n_classes = len(class_names)

    # Compute ROC curve and ROC area for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_probs[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Plot ROC curves
    plt.figure(figsize=(8, 6))
    for i in range(n_classes):
        plt.plot(fpr[i], tpr[i], label=f'ROC curve (class {class_names[i]}, area = {roc_auc[i]:.2f})')
    plt.plot([0, 1], [0, 1], color='red', linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve for {model_name} (One-vs-Rest)')
    plt.legend(loc='lower right')
    plt.show()

# Plot ROC curve for DINOv2
plot_roc_curve(dino_labels, np.array(dino_probs), class_names, 'DINOv2')


# Model evaluation results
results_df = pd.DataFrame({
    'Model Name': ['DINOv2'],
    'Accuracy (%)': [round(dino_accuracy, 2)],  # Round to 2 decimal places
    'Precision': [round(dino_precision, 2)],    # Round to 2 decimal places
    'Recall': [round(dino_recall, 2)],          # Round to 2 decimal places
    'F1 Score': [round(dino_f1, 2)],            # Round to 2 decimal places
    'Latency (ms)': [round(dino_latency, 2)]    # Round to 2 decimal places
})

# Display results in a table
plt.figure(figsize=(8, 4))
plt.axis('off')
table = plt.table(cellText=results_df.values,
                  colLabels=results_df.columns,
                  cellLoc='center', 
                  loc='center')
table.auto_set_font_size(False)
table.set_fontsize(12)
table.scale(1.2, 1.2)  # Scale table size
plt.title('DINOv2 Evaluation Results', fontsize=16)
plt.show()

# %%
import time
import torch
import numpy as np
import matplotlib.pyplot as plt

# Function to measure inference time for different batch sizes
def batch_wise_inference_analysis(model, dataset, device, batch_sizes):
    inference_times = []
    model.eval()

    for batch_size in batch_sizes:
        dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=False)
        total_time = 0
        total_samples = 0

        with torch.no_grad():
            for images, _ in dataloader:
                images = images.to(device)

                start_time = time.time()
                _ = model(images)  # Perform inference
                end_time = time.time()

                total_time += (end_time - start_time) * 1000  # Convert to milliseconds
                total_samples += images.size(0)

        avg_time_per_sample = total_time / total_samples
        inference_times.append(avg_time_per_sample)

        print(f"Batch Size: {batch_size}, Avg Inference Time per Sample: {avg_time_per_sample:.2f} ms")

    return inference_times

# Define batch sizes to test
batch_sizes = [1, 2, 4, 8, 16, 32, 64]

# Perform batch-wise inference analysis
inference_times = batch_wise_inference_analysis(model_dino, test_data, device, batch_sizes)

# Plot the results
plt.figure(figsize=(10, 6))
plt.plot(batch_sizes, inference_times, marker='o', linestyle='-', color='b')
plt.title('Batch-wise Inference Time Analysis')
plt.xlabel('Batch Size')
plt.ylabel('Average Inference Time per Sample (ms)')
plt.grid(True)
plt.xticks(batch_sizes)
plt.show()
# Out:
# Batch Size: 1, Avg Inference Time per Sample: 13.23 ms
# Batch Size: 2, Avg Inference Time per Sample: 6.31 ms
# Batch Size: 4, Avg Inference Time per Sample: 2.81 ms
# Batch Size: 8, Avg Inference Time per Sample: 1.61 ms
# Batch Size: 16, Avg Inference Time per Sample: 0.65 ms
# Batch Size: 32, Avg Inference Time per Sample: 0.37 ms
# Batch Size: 64, Avg Inference Time per Sample: 0.35 ms

# %%
from transformers import Dinov2ForImageClassification
import torch
import torch.onnx
import onnx

# Instantiate the model with the correct number of classes
model = Dinov2ForImageClassification.from_pretrained(
    "facebook/dinov2-base",
    num_labels=5  # Set this to the number of classes in your saved model
).to("cpu")  # Move the model to CPU

# Load the state dictionary
state_dict = torch.load(r"C:\Users\shiva\Desktop\EXCEED\ModelWrappers\BridgeDefects\Dinov2\dinov2_backboned_grayscale.pth", weights_only=True)

# Load the state dictionary into the model
model.load_state_dict(state_dict)

# Set the model to evaluation mode
model.eval()

# Define a dummy input with a smaller batch size
batch_size = 1  # Reduce batch size to 1
dummy_input = torch.randn(batch_size, 3, 224, 224).to("cpu")  # Move input to CPU

# Export the model to ONNX with dynamic batch size and opset version 14
onnx_path = "model_dino.onnx"
torch.onnx.export(
    model,  # Your PyTorch model
    dummy_input,  # Dummy input
    onnx_path,  # Output ONNX file path
    input_names=["input"],  # Input name
    output_names=["output"],  # Output name
    dynamic_axes={
        "input": {0: "batch_size"},  # Dynamic batch size for input
        "output": {0: "batch_size"}  # Dynamic batch size for output
    },
    opset_version=14  # Use opset version 14 or higher
)

print(f"Model exported to {onnx_path}")
# Out:
# Some weights of Dinov2ForImageClassification were not initialized from the model checkpoint at facebook/dinov2-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
# Model exported to model_dino.onnx

# %%
# Example input tensor (batch_size=1, channels=3, height=224, width=224)
input_data = torch.randn(1, 3, 224, 224).to(device)  # Adjust height and width as needed

# %%
from transformers import Dinov2ForImageClassification
import torch
import time
import numpy as np
import tensorrt as trt
import pycuda.driver as cuda
import pycuda.autoinit
from torchvision import transforms
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder

def load_pytorch_model(model_path, num_classes=5):
    """Load PyTorch model with proper initialization"""
    # Create model instance first
    model = Dinov2ForImageClassification.from_pretrained("facebook/dinov2-base", num_labels=num_classes)
    # Load saved state dict
    state_dict = torch.load(model_path)
    model.load_state_dict(state_dict)
    return model

def measure_pytorch_inference(model, dataloader, device):
    """Measure PyTorch model inference time"""
    model.eval()
    latencies = []
    
    with torch.no_grad():
        for images, _ in dataloader:
            images = images.to(device)
            
            # Warm-up runs
            for _ in range(10):
                _ = model(images).logits
            
            # Actual measurement
            start_time = time.time()
            _ = model(images).logits
            end_time = time.time()
            
            latencies.append((end_time - start_time) * 1000)
    
    return np.mean(latencies)

def measure_tensorrt_inference(engine, dataloader):
    """Measure TensorRT engine inference time"""
    context = engine.create_execution_context()
    latencies = []
    
    for images, _ in dataloader:
        input_batch = images.numpy()
        
        # Allocate device memory
        d_input = cuda.mem_alloc(input_batch.nbytes)
        output = np.empty((images.shape[0], 5), dtype=np.float32)
        d_output = cuda.mem_alloc(output.nbytes)
        
        stream = cuda.Stream()
        
        # Warm-up runs
        for _ in range(10):
            cuda.memcpy_htod_async(d_input, input_batch, stream)
            context.execute_async_v3(stream_handle=stream.handle)
            cuda.memcpy_dtoh_async(output, d_output, stream)
            stream.synchronize()
        
        # Actual measurement
        start_time = time.time()
        cuda.memcpy_htod_async(d_input, input_batch, stream)
        context.execute_async_v3(stream_handle=stream.handle)
        cuda.memcpy_dtoh_async(output, d_output, stream)
        stream.synchronize()
        end_time = time.time()
        
        latencies.append((end_time - start_time) * 1000)
        
        d_input.free()
        d_output.free()
    
    return np.mean(latencies)

def main():
    # Setup
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    transform = transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])
    
    # Load dataset
    dataset = ImageFolder(
        r"C:\Users\shiva\Desktop\EXCEED\ModelWrappers\BridgeDefects\Dinov2\updated_gs\valid", 
        transform=transform
    )
    dataloader = DataLoader(dataset, batch_size=16, shuffle=False)

    # Load and prepare PyTorch model
    pytorch_model = load_pytorch_model(
        r"C:\Users\shiva\Desktop\EXCEED\ModelWrappers\BridgeDefects\Dinov2\assets\dinov2_backboned_grayscale.pth"
    )
    pytorch_model = pytorch_model.to(device)
    
    # Load TensorRT engine
    TRT_LOGGER = trt.Logger(trt.Logger.WARNING)
    runtime = trt.Runtime(TRT_LOGGER)
    with open(r"C:\Users\shiva\Desktop\EXCEED\ModelWrappers\BridgeDefects\Dinov2\assets\model.trt", "rb") as f:
        trt_engine = runtime.deserialize_cuda_engine(f.read())
    
    # Measure inference times
    print("Measuring PyTorch inference time...")
    pytorch_latency = measure_pytorch_inference(pytorch_model, dataloader, device)
    print(f"PyTorch Average Inference Time: {pytorch_latency:.2f} ms")
    
    print("\nMeasuring TensorRT inference time...")
    tensorrt_latency = measure_tensorrt_inference(trt_engine, dataloader)
    print(f"TensorRT Average Inference Time: {tensorrt_latency:.2f} ms")
    
    # Compare results
    speedup = pytorch_latency / tensorrt_latency if tensorrt_latency > 0 else float('inf')
    print(f"\nSpeedup: {speedup:.2f}x")
    if tensorrt_latency < pytorch_latency:
        print("TensorRT optimization successful!")
    else:
        print("TensorRT is slower than PyTorch. Consider checking configuration.")

if __name__ == "__main__":
    main()
# Out:
# Some weights of Dinov2ForImageClassification were not initialized from the model checkpoint at facebook/dinov2-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# C:\Users\shiva\AppData\Local\Temp\ipykernel_10356\2884458283.py:17: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(model_path)
# Measuring PyTorch inference time...
# PyTorch Average Inference Time: 488.65 ms
#
# Measuring TensorRT inference time...
# TensorRT Average Inference Time: 4.30 ms
#
# Speedup: 113.56x
# TensorRT optimization successful!
